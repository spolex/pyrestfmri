# %% [markdown]
# Configurar matplotlib para ver las gráficas en linea

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from niwidgets import NiftiWidget
import ipywidgets as widgets
from nilearn import (image, plotting)

# %%
results_path = "../../results/output/preproc/*"
list_subjs = !ls -d $results_path | grep session

# %%
subj_id_selector = widgets.Select(
    options=list_subjs,
    # value='C575',
    # rows=10,
    description='Subject Id:',
    disabled=False
)
#subj_id_selector.on_trait_change(run_cells_below)
display(subj_id_selector)
# Out:
# Select(description='Subject Id:', options=('../../results/output/preproc/_session_id_1_subject_id_C113', '../.…

# %% [markdown]
# Lazy load del atlas y del archivo de neuroimagen para probar el atlas

# %%
fsl_prob_cerebelo = "../../datos/TEMPLATES/Cerebellum-MNIfnirt-prob-1mm.nii.gz"
func_filenames = subj_id_selector.value+"/applyTransFunc/f1_trim_st_mcf_trans.nii.gz"
func_filenames
# Out:
# '../../results/output/preproc/_session_id_1_subject_id_C234/applyTransFunc/f1_trim_st_mcf_trans.nii.gz'

# %% [markdown]
# NiftiMapsMasker para extraer las señales del cerebelo. NiftiMapsMasker es útil cuando se deben extraer datos de volúmenes superpuestos

# %%
from nilearn.input_data import NiftiMapsMasker
masker = NiftiMapsMasker(maps_img=fsl_prob_cerebelo,memory='nilearn_cache', verbose=True, standardize=True)

# %% [markdown]
# Overview de algunos indicadores de las imagenes

# %%
import nibabel as nb
fmri_img = nb.load(func_filenames)
cbl_img = nb.load(fsl_prob_cerebelo)

# %%
print(fmri_img.shape)
print(cbl_img.shape)
# Out:
# (61, 73, 61, 158)
# (182, 218, 182, 28)

# %%
n_regions = cbl_img.shape[-1]
n_regions
# Out:
# 28

# %%
title = ('%d regions are extracted from cerebellum atlas' % (n_regions)) 
plotting.plot_prob_atlas(cbl_img, view_type='filled_contours',title=title)
# Out:
# /opt/miniconda-latest/envs/elekin/lib/python3.7/site-packages/nilearn/plotting/displays.py:98: UserWarning: No contour levels were found within the data range.
#   **kwargs)
# /opt/miniconda-latest/envs/elekin/lib/python3.7/site-packages/numpy/ma/core.py:2786: UserWarning: Warning: converting a masked element to nan.
#   order=order, subok=True, ndmin=ndmin)
# /opt/miniconda-latest/envs/elekin/lib/python3.7/site-packages/nilearn/plotting/displays.py:98: UserWarning: linewidths is ignored by contourf
#   **kwargs)

# %% [markdown]
# Entrenamiento del modelo para aplicar la extracción del cerebelo

# %%
masker.fit()
# Out:
# [NiftiMapsMasker.fit] loading regions from ../../datos/TEMPLATES/Cerebellum-MNIfnirt-prob-1mm.nii.gz
# NiftiMapsMasker(allow_overlap=True, detrend=False, dtype=None, high_pass=None,
#         low_pass=None,
#         maps_img='../../datos/TEMPLATES/Cerebellum-MNIfnirt-prob-1mm.nii.gz',
#         mask_img=None, memory='nilearn_cache', memory_level=0,
#         resampling_target='data', smoothing_fwhm=None, standardize=True,
#         t_r=None, verbose=True)

# %% [markdown]
# Extracción de las series temporales dado el atlas de probabilidad del cerebelo a partir de las imágenes fmri.

# %%
timeseries_subject = masker.transform(func_filenames, confounds=None)

# %% [markdown]
# Gráfica de las 28 series temporales extraidas

# %%
fig = plt.figure()
plt.plot(timeseries_subject)
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
timeseries_subject.shape
